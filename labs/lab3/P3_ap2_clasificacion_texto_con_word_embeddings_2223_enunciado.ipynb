# %% [markdown]
# # Práctica 2: Procesamiento del Lenguaje Natural
#
# __Fecha de entrega: 8 de mayo de 2023__
#
# El objetivo de esta práctica es aplicar los conceptos teóricos vistos en clase en el módulo de PLN. La práctica consta de 2 notebooks que se entregarán simultáneamente en la tarea de entrega habilitada en el Campus  Virtual.
#
# Lo más importante en esta práctica no es el código Python, sino el análisis de los datos y modelos que construyas y las explicaciones razonadas de cada una de las decisiones que tomes. __No se valorarán trozos de código o gráficas sin ningún tipo de contexto o explicación__.
#
# Finalmente, recuerda establecer el parámetro `random_state` en todas las funciones que tomen decisiones aleatorias para que los resultados sean reproducibles (los resultados no varíen entre ejecuciones).

# %%
RANDOM_STATE = 1234

# %% [markdown]
# # Apartado 1: Análisis de sentimientos con word embeddings

# %% [markdown]
# __Número de grupo: 20__
#
# __Nombres de los estudiantes: Alejandro Barrachina Argudo y Juan Pablo Corella Martín__

# %% [markdown]
# ## 1) Carga del conjunto de datos
#
# El fichero `IMBD_Dataset.csv` contiene opiniones de películas clasificadas en 2 categorías diferentes (positiva/negativa).
#
# Este set de datos se creó utilizando el "IMDB Dataset of 50K Movie Reviews", el cual contiene 50,000 reseñas de películas con un sentimiento positivo o negativo adjunto a ellas.
#
# Muestra un ejemplo de cada clase.
#
# Haz un estudio del conjunto de datos. ¿qué palabras aparecen más veces?, ¿tendría sentido normalizar de alguna manera el corpus?
#
# Crea una partición de los datos dejando el 80% para entrenamiento y el 20% restante para test usando la función `train_test_split` de sklearn.

# %%
# acceso a google drive

# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np

# %%
# imbd_file = '/content/drive/MyDrive/IA2/p3/IMDB_Dataset.csv'
imbd_file = './IMDB_Dataset.csv'

df=pd.read_csv(imbd_file)
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print("Positivo:\n" + df.review[0])
print("Negativo:\n" + df.review[3])
# Out:
# Positivo:
# One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side.
# Negativo:
# Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them.

# %% [markdown]
# Tiene sentido normalizar el corpus, ya que el texto extraido incluye tags HTML, signos de puntuación y mayúsculas.

# %%
import nltk
import re
from os import path, getcwd

nltk_path = path.join(getcwd(), 'data')
nltk.data.path.append(nltk_path)
# nltk.download('stopwords', nltk_path)

wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')


def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub('<br />', ' ', doc)
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I | re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc


normalize_corpus = np.vectorize(normalize_document)

# %%
df.review = normalize_corpus(df.review)

# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences

max_words = 1500    # cogeremos las 1500 palabras más frecuentes
max_comment_length = 20 #las secuencias tendrán 20 palabras, el resto serán ceros

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(df.review)

sequences = tokenizer.texts_to_sequences(df.review)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
max_words = len(word_index)

data = pad_sequences(sequences, maxlen=max_comment_length)
# Out:
# Found 162148 unique tokens.

# %%
word_index.keys()
# Out:
# dict_keys(['movie', 'film', 'one', 'like', 'good', 'even', 'would', 'time', 'really', 'see', 'story', 'well', 'much', 'get', 'bad', 'great', 'also', 'people', 'first', 'dont', 'movies', 'made', 'films', 'way', 'make', 'could', 'characters', 'think', 'watch', 'many', 'seen', 'two', 'character', 'never', 'love', 'acting', 'plot', 'best', 'know', 'little', 'show', 'life', 'ever', 'better', 'end', 'still', 'scene', 'say', 'man', 'scenes', 'something', 'go', 'im', 'back', 'watching', 'real', 'thing', 'doesnt', 'actors', 'didnt', 'years', 'though', 'funny', 'another', 'actually', 'makes', 'nothing', 'work', 'find', 'look', 'going', 'lot', 'new', 'every', 'old', 'us', 'part', 'director', 'cant', 'thats', 'things', 'want', 'cast', 'quite', 'pretty', 'seems', 'around', 'world', 'young', 'got', 'take', 'however', 'fact', 'enough', 'horror', 'big', 'thought', 'ive', 'give', 'may', 'long', 'without', 'right', 'isnt', 'music', 'saw', 'always', 'times', 'gets', 'original', 'series', 'comedy', 'come', 'almost', 'role', 'must', 'theres', 'interesting', 'whole', 'least', 'guy', 'point', 'action', 'done', 'bit', 'minutes', 'script', 'far', 'might', 'anything', 'hes', 'since', 'feel', 'last', 'family', 'probably', 'performance', 'kind', 'away', 'tv', 'yet', 'worst', 'fun', 'rather', 'sure', 'anyone', 'found', 'played', 'girl', 'making', 'believe', 'woman', 'although', 'shows', 'trying', 'course', 'especially', 'day', 'hard', 'comes', 'everything', 'goes', 'put', 'dvd', 'ending', 'worth', 'different', 'place', 'maybe', 'looking', 'main', 'screen', 'book', 'sense', 'wasnt', 'looks', 'reason', 'watched', 'three', 'set', 'true', 'money', 'effects', 'job', 'someone', 'together', 'play', 'plays', 'actor', 'said', 'instead', 'everyone', 'later', 'seem', 'takes', 'audience', 'american', 'special', 'beautiful', 'seeing', 'war', 'left', 'excellent', 'john', 'version', 'idea', 'night', 'shot', 'black', 'simply', 'fan', 'high', 'youre', 'else', 'house', 'completely', 'death', 'nice', 'used', 'poor', 'kids', 'wife', 'read', 'along', 'friends', 'short', 'help', 'year', 'second', 'mind', 'either', 'star', 'home', 'men', 'boring', 'less', 'enjoy', 'try', 'given', 'use', 'need', 'half', 'classic', 'wrong', 'rest', 'performances', 'truly', 'next', 'dead', 'production', 'stupid', 'line', 'recommend', 'father', 'hollywood', 'couple', 'start', 'tell', 'women', 'let', 'came', 'others', 'awful', 'getting', 'remember', 'understand', 'full', 'terrible', 'school', 'camera', 'moments', 'perhaps', 'keep', 'mean', 'sex', 'wonderful', 'playing', 'name', 'video', 'episode', 'budget', 'definitely', 'often', 'human', 'person', 'perfect', 'gives', 'top', 'face', 'small', 'couldnt', 'lines', 'early', 'dialogue', 'went', 'piece', 'guys', 'stars', 'absolutely', 'finally', 'case', 'certainly', 'title', 'head', 'become', 'liked', 'worse', 'loved', 'entertaining', 'hope', 'sort', 'yes', 'lost', 'style', 'felt', 'mother', 'entire', 'picture', 'supposed', 'overall', 'written', 'several', 'live', 'laugh', 'boy', 'cinema', 'problem', 'waste', 'friend', 'sound', 'beginning', 'oh', 'mr', 'based', 'totally', 'shes', 'fans', 'care', 'wanted', 'seemed', 'dark', 'id', 'humor', 'direction', 'throughout', 'despite', 'final', 'children', 'lives', 'example', 'guess', 'already', 'becomes', 'lead', 'wont', 'evil', 'game', 'youll', 'drama', 'turn', 'days', 'called', 'unfortunately', 'low', 'able', 'white', 'girls', 'wants', 'history', 'fine', 'quality', 'horrible', 'amazing', 'writing', 'works', 'theyre', 'killer', 'act', 'kill', 'tries', 'flick', 'michael', 'enjoyed', 'turns', 'past', 'gave', 'side', 'parts', 'son', 'favorite', 'matter', 'brilliant', 'stuff', 'eyes', 'behind', 'expect', 'ones', 'car', 'town', 'obviously', 'run', 'starts', 'viewer', 'sometimes', 'killed', 'soon', 'directed', 'etc', 'genre', 'thinking', 'heart', 'says', 'late', 'art', 'city', 'actress', 'group', 'took', 'decent', 'highly', 'ill', 'heard', 'happens', 'hell', 'feeling', 'experience', 'kid', 'child', 'anyway', 'except', ' ...

# %%
# tensorflow trabaja con variables numéricas,
# por lo que sustituimos los sentimientos
df.sentiment.replace({"positive": 1, "negative": 0}, inplace=True)

# %%
# Crea una partición de los datos dejando el 80% para entrenamiento y el 20% restante para test
# usando la función `train_test_split` de sklearn. 
#------------------------------------------------------------------------------

from sklearn.model_selection import train_test_split

d=df.values

x_train, x_test, y_train, y_test = train_test_split(data, df.sentiment, test_size=0.20, random_state=RANDOM_STATE, stratify = df.sentiment)

print("Training texts:", len(y_train))
print("Test texts:", len(y_test))
# Out:
# Training texts: 40000
# Test texts: 10000

# %% [markdown]
# ## 2) Estudio del efecto de distintas configuraciones de word embeddings para resolver la tara
#
# Usa distintas configuraciones de word embeddigns y discute los resultados obtenidos.

# %%
# Fijamos el tamaño de los embedding a 50 dimensiones

embedding_dim = 50

# %% [markdown]
# a) Sin Embeddings pre-entrenados

# %%
# MODELO 1. SIN EMBEDDINGS PRE-ENTRENADOS 

from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model1 = Sequential()
# We specify the maximum input length to our Embedding layer
# so we can later flatten the embedded inputs


model1.add(Embedding(max_words, embedding_dim, input_length=max_comment_length))
# After the Embedding layer, our activations have shape `(max_words, max_comment_length, embedding_dim)`.

# We flatten the 3D tensor of embeddings into a 2D tensor of shape `(max_words, max_comment_length * embedding_dim)`

model1.add(Flatten())

# We add the classifier on top
model1.add(Dense(1, activation='sigmoid'))

model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model1.summary()

print("Fitting...")
history = model1.fit(x_train, y_train,
                    epochs=20,
                    batch_size=32,
                    validation_data=(x_test, y_test),
                    use_multiprocessing=True)

print("Evaluating...")
score1 = model1.evaluate(x_test, y_test,
                    use_multiprocessing=True)

print("Accuracy: %.2f%%" % (score1[1]*100))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 20, 50)            8107400
#
#  flatten_3 (Flatten)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 8,108,401
# Trainable params: 8,108,401
# Non-trainable params: 0
# _________________________________________________________________
# Fitting...
# Epoch 1/20
# 1250/1250 [==============================] - 93s 74ms/step - loss: 0.4873 - accuracy: 0.7646 - val_loss: 0.4267 - val_accuracy: 0.8008
# Epoch 2/20
# 1250/1250 [==============================] - 93s 75ms/step - loss: 0.3942 - accuracy: 0.8185 - val_loss: 0.4290 - val_accuracy: 0.7985
# Epoch 3/20
# 1250/1250 [==============================] - 93s 75ms/step - loss: 0.3442 - accuracy: 0.8484 - val_loss: 0.4515 - val_accuracy: 0.7903
# Epoch 4/20
# 1250/1250 [==============================] - 93s 75ms/step - loss: 0.2879 - accuracy: 0.8828 - val_loss: 0.4896 - val_accuracy: 0.7773
# Epoch 5/20
# 1250/1250 [==============================] - 94s 75ms/step - loss: 0.2382 - accuracy: 0.9101 - val_loss: 0.5452 - val_accuracy: 0.7662
# Epoch 6/20
# 1250/1250 [==============================] - 94s 75ms/step - loss: 0.1973 - accuracy: 0.9301 - val_loss: 0.6100 - val_accuracy: 0.7593
# Epoch 7/20
# 1250/1250 [==============================] - 93s 74ms/step - loss: 0.1618 - accuracy: 0.9483 - val_loss: 0.6863 - val_accuracy: 0.7569
# Epoch 8/20
# 1250/1250 [==============================] - 93s 74ms/step - loss: 0.1333 - accuracy: 0.9605 - val_loss: 0.7703 - val_accuracy: 0.7507
# Epoch 9/20
# 1250/1250 [==============================] - 93s 74ms/step - loss: 0.1078 - accuracy: 0.9715 - val_loss: 0.8581 - val_accuracy: 0.7440
# Epoch 10/20
# 1250/1250 [==============================] - 95s 76ms/step - loss: 0.0862 - accuracy: 0.9808 - val_loss: 0.9557 - val_accuracy: 0.7428
# Epoch 11/20
# 1250/1250 [==============================] - 92s 74ms/step - loss: 0.0689 - accuracy: 0.9868 - val_loss: 1.0640 - val_accuracy: 0.7363
# Epoch 12/20
# 1250/1250 [==============================] - 89s 71ms/step - loss: 0.0538 - accuracy: 0.9916 - val_loss: 1.1723 - val_accuracy: 0.7335
# Epoch 13/20
# 1250/1250 [==============================] - 89s 71ms/step - loss: 0.0414 - accuracy: 0.9954 - val_loss: 1.2870 - val_accuracy: 0.7330
# Epoch 14/20
# 1250/1250 [==============================] - 94s 75ms/step - loss: 0.0317 - accuracy: 0.9971 - val_loss: 1.4074 - val_accuracy: 0.7285
# Epoch 15/20
# 1250/1250 [==============================] - 91s 73ms/step - loss: 0.0243 - accuracy: 0.9988 - val_loss: 1.5227 - val_accuracy: 0.7294
# Epoch 16/20
# 1250/1250 [==============================] - 92s 74ms/step - loss: 0.0181 - accuracy: 0.9994 - val_loss: 1.6473 - val_accuracy: 0.7255
# Epoch 17/20
# 1250/1250 [==============================] - 95s 76ms/step - loss: 0.0137 - accuracy: 0.9997 - val_loss: 1.7584 - val_accuracy: 0.7251
# Epoch 18/20
# 1250/1250 [==============================] - 91s 73ms/step - loss: 0.0106 - accuracy: 0.9998 - val_loss: 1.8879 - val_accuracy: 0.7260
# Epoch 19/20
# 1250/1250 [==============================] - 95s 76ms/step - loss: 0.0080 - accuracy: 0.9999 - val_loss: 2.0169 - val_accuracy: 0.7227
# Epoch 20/20
# 1250/1250 [==============================] - 94s 75ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.1341 - val_accuracy: 0.7251
# Evaluating...
# 313/313 [==============================] - 0s 603us/step - loss: 2.1341 - accuracy: 0.7251
# Accuracy: 72.51%

# %% [markdown]
# Usando directamente la capa de embedding obtenemos un 72.51% de accuracy.

# %% [markdown]
# ---------

# %% [markdown]
# b) Word embeddings pre-entrenados y congelados.

# %%
import numpy as np

embeddings_index = {}
with open('./glove.6B.50d.txt', encoding="UTF-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
# Construimos nuestra matriz
embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if i < max_words:
        if embedding_vector is not None:
            # Words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector

# %%
# Definimos el modelo y cargamos las word embeddings de GloVe
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense

model2 = Sequential()
model2.add(Embedding(max_words, embedding_dim, input_length=max_comment_length))
model2.add(Flatten())
model2.add(Dense(1, activation='sigmoid'))
model2.summary()

model2.layers[0].set_weights([embedding_matrix])
model2.layers[0].trainable = False  # El conjunto pre-entrenado no se verá afectado durante el entrenamiento

model2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

print("Fitting...")
history = model2.fit(x_train, y_train,
                    epochs=20,
                    batch_size=32,
                    validation_data=(x_test, y_test))

print("Evaluating...")
score2 = model2.evaluate(x_test, y_test)

print("Accuracy: %.2f%%" % (score2[1]*100))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 20, 50)            8107400
#
#  flatten_5 (Flatten)         (None, 1000)              0
#
#  dense_5 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 8,108,401
# Trainable params: 8,108,401
# Non-trainable params: 0
# _________________________________________________________________
# Fitting...
# Epoch 1/20
# 1250/1250 [==============================] - 1s 751us/step - loss: 0.6071 - accuracy: 0.6680 - val_loss: 0.5737 - val_accuracy: 0.6959
# Epoch 2/20
# 1250/1250 [==============================] - 1s 696us/step - loss: 0.5680 - accuracy: 0.7074 - val_loss: 0.5723 - val_accuracy: 0.6989
# Epoch 3/20
# 1250/1250 [==============================] - 1s 703us/step - loss: 0.5643 - accuracy: 0.7097 - val_loss: 0.5760 - val_accuracy: 0.7017
# Epoch 4/20
# 1250/1250 [==============================] - 1s 708us/step - loss: 0.5639 - accuracy: 0.7095 - val_loss: 0.5737 - val_accuracy: 0.7000
# Epoch 5/20
# 1250/1250 [==============================] - 1s 717us/step - loss: 0.5639 - accuracy: 0.7077 - val_loss: 0.5728 - val_accuracy: 0.6998
# Epoch 6/20
# 1250/1250 [==============================] - 1s 743us/step - loss: 0.5630 - accuracy: 0.7103 - val_loss: 0.5727 - val_accuracy: 0.7023
# Epoch 7/20
# 1250/1250 [==============================] - 1s 710us/step - loss: 0.5633 - accuracy: 0.7094 - val_loss: 0.5726 - val_accuracy: 0.7008
# Epoch 8/20
# 1250/1250 [==============================] - 1s 715us/step - loss: 0.5634 - accuracy: 0.7095 - val_loss: 0.5726 - val_accuracy: 0.6975
# Epoch 9/20
# 1250/1250 [==============================] - 1s 697us/step - loss: 0.5628 - accuracy: 0.7091 - val_loss: 0.5807 - val_accuracy: 0.6952
# Epoch 10/20
# 1250/1250 [==============================] - 1s 706us/step - loss: 0.5631 - accuracy: 0.7115 - val_loss: 0.5727 - val_accuracy: 0.6983
# Epoch 11/20
# 1250/1250 [==============================] - 1s 891us/step - loss: 0.5617 - accuracy: 0.7107 - val_loss: 0.5728 - val_accuracy: 0.6993
# Epoch 12/20
# 1250/1250 [==============================] - 1s 711us/step - loss: 0.5622 - accuracy: 0.7108 - val_loss: 0.5869 - val_accuracy: 0.6892
# Epoch 13/20
# 1250/1250 [==============================] - 1s 708us/step - loss: 0.5626 - accuracy: 0.7112 - val_loss: 0.5722 - val_accuracy: 0.7015
# Epoch 14/20
# 1250/1250 [==============================] - 1s 692us/step - loss: 0.5629 - accuracy: 0.7088 - val_loss: 0.5724 - val_accuracy: 0.7008
# Epoch 15/20
# 1250/1250 [==============================] - 1s 693us/step - loss: 0.5618 - accuracy: 0.7117 - val_loss: 0.5726 - val_accuracy: 0.7005
# Epoch 16/20
# 1250/1250 [==============================] - 1s 760us/step - loss: 0.5621 - accuracy: 0.7121 - val_loss: 0.5760 - val_accuracy: 0.6978
# Epoch 17/20
# 1250/1250 [==============================] - 1s 748us/step - loss: 0.5619 - accuracy: 0.7125 - val_loss: 0.5725 - val_accuracy: 0.6975
# Epoch 18/20
# 1250/1250 [==============================] - 1s 727us/step - loss: 0.5614 - accuracy: 0.7129 - val_loss: 0.5731 - val_accuracy: 0.6984
# Epoch 19/20
# 1250/1250 [==============================] - 1s 729us/step - loss: 0.5611 - accuracy: 0.7112 - val_loss: 0.5726 - val_accuracy: 0.7006
# Epoch 20/20
# 1250/1250 [==============================] - 1s 738us/step - loss: 0.5608 - accuracy: 0.7115 - val_loss: 0.5752 - val_accuracy: 0.6985
# Evaluating...
# 313/313 [==============================] - 0s 623us/step - loss: 0.5752 - accuracy: 0.6985
# Accuracy: 69.85%

# %% [markdown]
# El accuracy en este caso es del 69.85%, pero que el anterior aunque tardando mucho menos gracias al pre-entrenamiento.

# %% [markdown]
# C) Word embeddings pre-entrenados sin congelar.

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense

model3 = Sequential()
model3.add(Embedding(max_words, embedding_dim, input_length=max_comment_length))
model3.add(Flatten())
model3.add(Dense(1, activation='sigmoid'))
model3.summary()

model3.layers[0].set_weights([embedding_matrix])
model3.layers[0].trainable = True

model3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
history = model3.fit(x_train, y_train,
                    epochs=20,
                    batch_size=32,
                    validation_data=(x_test, y_test))

score3 = model3.evaluate(x_test, y_test)

print("Accuracy: %.2f%%" % (score3[1]*100))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 20, 50)            8107400
#
#  flatten_6 (Flatten)         (None, 1000)              0
#
#  dense_6 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 8,108,401
# Trainable params: 8,108,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1250/1250 [==============================] - 91s 72ms/step - loss: 0.5446 - accuracy: 0.7136 - val_loss: 0.4647 - val_accuracy: 0.7793
# Epoch 2/20
# 1250/1250 [==============================] - 91s 73ms/step - loss: 0.4253 - accuracy: 0.8012 - val_loss: 0.4392 - val_accuracy: 0.7930
# Epoch 3/20
# 1250/1250 [==============================] - 91s 73ms/step - loss: 0.3943 - accuracy: 0.8196 - val_loss: 0.4585 - val_accuracy: 0.7832
# Epoch 4/20
# 1250/1250 [==============================] - 93s 75ms/step - loss: 0.3696 - accuracy: 0.8333 - val_loss: 0.4550 - val_accuracy: 0.7892
# Epoch 5/20
# 1250/1250 [==============================] - 91s 73ms/step - loss: 0.3444 - accuracy: 0.8479 - val_loss: 0.4730 - val_accuracy: 0.7835
# Epoch 6/20
# 1250/1250 [==============================] - 91s 73ms/step - loss: 0.3178 - accuracy: 0.8648 - val_loss: 0.4922 - val_accuracy: 0.7782
# Epoch 7/20
# 1250/1250 [==============================] - 90s 72ms/step - loss: 0.2897 - accuracy: 0.8773 - val_loss: 0.5195 - val_accuracy: 0.7693
# Epoch 8/20
# 1250/1250 [==============================] - 90s 72ms/step - loss: 0.2646 - accuracy: 0.8917 - val_loss: 0.5584 - val_accuracy: 0.7637
# Epoch 9/20
# 1250/1250 [==============================] - 91s 73ms/step - loss: 0.2404 - accuracy: 0.9048 - val_loss: 0.6033 - val_accuracy: 0.7555
# Epoch 10/20
# 1250/1250 [==============================] - 91s 73ms/step - loss: 0.2170 - accuracy: 0.9177 - val_loss: 0.6321 - val_accuracy: 0.7590
# Epoch 11/20
# 1250/1250 [==============================] - 89s 71ms/step - loss: 0.1956 - accuracy: 0.9276 - val_loss: 0.6853 - val_accuracy: 0.7485
# Epoch 12/20
# 1250/1250 [==============================] - 87s 70ms/step - loss: 0.1761 - accuracy: 0.9373 - val_loss: 0.7310 - val_accuracy: 0.7498
# Epoch 13/20
# 1250/1250 [==============================] - 85s 68ms/step - loss: 0.1566 - accuracy: 0.9475 - val_loss: 0.7818 - val_accuracy: 0.7465
# Epoch 14/20
# 1250/1250 [==============================] - 86s 69ms/step - loss: 0.1391 - accuracy: 0.9557 - val_loss: 0.8381 - val_accuracy: 0.7437
# Epoch 15/20
# 1250/1250 [==============================] - 91s 73ms/step - loss: 0.1221 - accuracy: 0.9642 - val_loss: 0.8993 - val_accuracy: 0.7428
# Epoch 16/20
# 1250/1250 [==============================] - 86s 69ms/step - loss: 0.1066 - accuracy: 0.9714 - val_loss: 0.9624 - val_accuracy: 0.7414
# Epoch 17/20
# 1250/1250 [==============================] - 89s 71ms/step - loss: 0.0919 - accuracy: 0.9781 - val_loss: 1.0387 - val_accuracy: 0.7365
# Epoch 18/20
# 1250/1250 [==============================] - 89s 71ms/step - loss: 0.0782 - accuracy: 0.9834 - val_loss: 1.1178 - val_accuracy: 0.7343
# Epoch 19/20
# 1250/1250 [==============================] - 90s 72ms/step - loss: 0.0662 - accuracy: 0.9884 - val_loss: 1.1911 - val_accuracy: 0.7334
# Epoch 20/20
# 1250/1250 [==============================] - 94s 76ms/step - loss: 0.0550 - accuracy: 0.9918 - val_loss: 1.2776 - val_accuracy: 0.7321
# 313/313 [==============================] - 0s 777us/step - loss: 1.2776 - accuracy: 0.7321
# Accuracy: 73.21%

# %% [markdown]
# El accuracy en este ultimo caso es de 73.21%, el mejor resultado.

# %% [markdown]
# ## 3) Análisis final
#
# Analiza con detalle el mejor clasificador. Busca un ejemplo mal clasificado de cada clase, justifica el error ¿se te ocurre alguna forma de solucionarlo?
#
# Compara los resultados obtenidos con y sin word embeddings

# %%
print("Sin word embeddings pre-entrenados")
print("Accuracy: %.2f%%" % (score1[1]*100))
print("Con word embeddings pre-entrenados congelados")
print("Accuracy: %.2f%%" % (score2[1]*100))
print("Con word embeddings pre-entrenados sin congelar")
print("Accuracy: %.2f%%" % (score3[1]*100))
# Out:
# Sin word embeddings pre-entrenados
# Accuracy: 72.51%
# Con word embeddings pre-entrenados congelados
# Accuracy: 69.85%
# Con word embeddings pre-entrenados sin congelar
# Accuracy: 73.21%

# %% [markdown]
# TODO: EXPLICAR QUE LOS RESULTADOS SON PEORES EN EL SEGUNDO POR USARSE UNAS WORD EMBEDDINGS GENERALES SIN QUE PUEDAN REAJUSTARSE A UN CORPUS DE TEXTOS TAN GRANDE, COSA QUE SE ARREGLA EN EL TERCERO.

# %% [markdown]
# TODO: COMPARAR CON LOS RESULTADOS DEL OTRO NOTEBOOK
